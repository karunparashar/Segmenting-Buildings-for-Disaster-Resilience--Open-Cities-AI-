# %%
import os
import tensorflow as tf

# %%
import numpy as np
width = 128
height = 128
channel =3
train_path = '/Users/karunparashar/Downloads/opencityAI/image_train/'
mask_path = '/Users/karunparashar/Downloads/opencityAI/mask_train/'
#the following piece walks through the available folders within the train_path and mask_path respectively
train_id = next(os.walk(train_path))[2]
mask_id = next(os.walk(mask_path))[2]
#to create X and Y arrays to be later filled with images of both images and masks
x_train = np.zeros((len(train_id),height,width,channel),dtype = np.uint8)
y_train = np.zeros((len(mask_id),height,width,1),dtype = np.bool)

# %%
# next(os.walk("/Users/karunparashar/Downloads/"))[2]

# %%
x_train.shape
# Out:
# (414, 128, 128, 3)

# %%
! pip install imageio
# Out:
# Requirement already satisfied: imageio in /anaconda3/lib/python3.7/site-packages (2.6.1)
# Requirement already satisfied: pillow in /anaconda3/lib/python3.7/site-packages (from imageio) (7.0.0)
# Requirement already satisfied: numpy in /anaconda3/lib/python3.7/site-packages (from imageio) (1.18.1)

# %%
# for i in next(os.walk("/Users/karunparashar/Downloads/opencityAI/masks-256/"))[2]:
#     print(type(i))
from skimage.io import imread,imshow
from skimage.transform import resize
import imageio as i_o
import cv2
imshow(imageio.imread('acc_665946_0_19_261799_253906.png'))

# %%
# from tqdm import tqdm
# from skimage.io import imread,imshow
# from skimage.transform import resize
# import matplotlib.pyplot as plt
# import cv2
# print("resizing training images and masks")
# for n,id_ in tqdm(enumerate(train_id),total=len(train_id)):
#     path = train_path+id_
#     img = imread(path)[:,:,:channel]
#     img = resize(img,(height,width),mode ='constant',preserve_range =True)
#     x_train[n] = img
#     for mask_file in tqdm(enumerate(mask_id),total=len(mask_id)):
#         mask_ = imread(path+mask_file)
#         mask_ = np.expand_dims(resize(mask_,(height,width),mode ='constant',preserve_range =True))
#         mask=np.maximum(mask,mask_)
#     y_train[n] = mask

# %%
from tqdm import tqdm
from skimage.io import imread,imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
import cv2
print("resizing training images and masks")
for n,id_ in tqdm(enumerate(train_id),total=len(train_id)):
    path = train_path+id_
    img = imread(path)[:,:,:channel]
    img = resize(img,(height,width),mode ='constant',preserve_range =True)
    x_train[n] = img
mask = np.zeros((height,width,1),dtype = np.bool)
for n2,id2_ in tqdm(enumerate(mask_id),total=len(mask_id)):
    path2 = mask_path+id2_
    mask_ = imread(path2)
#     print(mask_.shape)
    mask_ = np.expand_dims(resize(mask_,(height,width),mode ='constant',preserve_range =True),axis=-1)
#     print(mask_.shape)
    y_train[n2]=mask_
# Out:
#   0%|          | 2/414 [00:00<00:25, 16.20it/s]
# resizing training images and masks
#  10%|█         | 43/414 [00:02<00:23, 15.63it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-26468b5c1393> in <module>
#       7 for n,id_ in tqdm(enumerate(train_id),total=len(train_id)):
#       8     path = train_path+id_
# ----> 9     img = imread(path)[:,:,:channel]
#      10     img = resize(img,(height,width),mode ='constant',preserve_range =True)
#      11     x_train[n] = img
#
# //anaconda3/lib/python3.7/site-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# //anaconda3/lib/python3.7/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     208                                (plugin, kind))
#     209
# --> 210     return func(*args, **kwargs)
#     211
#     212
#
# //anaconda3/lib/python3.7/site-packages/skimage/io/_plugins/imageio_plugin.py in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ---> 10     return np.asarray(imageio_imread(*args, **kwargs))
#
# //anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     262
#     263     # Get reader and read first
# --> 264     reader = read(uri, format, "i", **kwargs)
#     265     with reader:
#     266         return reader.get_data(0)
#
# //anaconda3/lib/python3.7/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     180     if format is None:
#     181         raise ValueError(
# --> 182             "Could not find a format to read the specified file " "in mode %r" % mode
#     183         )
#     184
#
# ValueError: Could not find a format to read the specified file in mode 'i'

# %%
import random
image_x = random.randint(0,20)
imshow(x_train[image_x])
plt.show()
imshow(np.squeeze(y_train[image_x]))
plt.show()

# %%
y_train.shape
# Out:
# (200, 256, 256, 1)

# %%
x_train.shape
# Out:
# (200, 256, 256, 3)
